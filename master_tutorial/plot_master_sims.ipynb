# %%
library(rjson)

# %%
df <- fromJSON(file = 'SIR_output.json')

# %%
par(mfrow =c(2, 2))
plot(df$t, df$I, type = 'l', ylim = c(-1, 8.5))
lines(df$t, df$R, col = 'red')
plot(df$t, df$S, col = 'blue', type = 'l')
# Out:
# plot without title

# %%
df$
